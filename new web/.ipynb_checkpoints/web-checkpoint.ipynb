# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go

# %%
AbVolume_df = "Resources/csvData.csv"

AbVolume_df = pd.read_csv("Resources/csvData.csv")
AbVolume_df.head()
# Out:
#           State  abortionRate  totalAbortions  totalBirths  abortionClinics  \
# 0       Wyoming           1.3             140         6903                2
# 1  South Dakota           3.1             500        12134                1
# 2      Kentucky           3.8            3200        54752                1
# 3         Idaho           3.9            1290        22181                3
# 4      Missouri           4.0            4710        73034                3
#
#    abortionRatio
# 0         0.0199
# 1         0.0396
# 2         0.0552
# 3         0.0550
# 4         0.0606

# %%
html_AbVolume_df = AbVolume_df.to_html()
print(html_AbVolume_df)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>abortionRate</th>
#       <th>totalAbortions</th>
#       <th>totalBirths</th>
#       <th>abortionClinics</th>
#       <th>abortionRatio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Wyoming</td>
#       <td>1.3</td>
#       <td>140</td>
#       <td>6903</td>
#       <td>2</td>
#       <td>0.0199</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>South Dakota</td>
#       <td>3.1</td>
#       <td>500</td>
#       <td>12134</td>
#       <td>1</td>
#       <td>0.0396</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Kentucky</td>
#       <td>3.8</td>
#       <td>3200</td>
#       <td>54752</td>
#       <td>1</td>
#       <td>0.0552</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Idaho</td>
#       <td>3.9</td>
#       <td>1290</td>
#       <td>22181</td>
#       <td>3</td>
# ...

# %%
html_AbVolume_df.to_html('./Resources/csvData.html', index=False)

# %%
AbTimeline_df = pd.read_csv('Resources/NationalAndStatePregnancy_PublicUse.csv')
AbTimeline_df.head()
# Out:
#   state  year  pregnancyratelt15  pregnancyrate1517  pregnancyrate1819  \
# 0    AL  1988               21.3               78.3              155.7
# 1    AL  1992               23.6               76.3              173.4
# 2    AL  1996               18.5               66.2              156.2
# 3    AL  2000               11.9               53.7              140.8
# 4    AL  2005                8.7               38.6              118.7
#
#    pregnancyrate1519  pregnancyratelt20  pregnancyrate2024  pregnancyrate2529  \
# 0              110.5              114.3              186.5              152.5
# 1              116.4              120.9              184.2              155.0
# 2              102.4              106.0              176.6              143.2
# 3               89.8               92.1              186.8              158.7
# 4               70.8               72.5              165.8              154.8
#
# ...

# %%
html_AbTimeline_df = AbTimeline_df.to_html()
print(html_AbTimeline_df)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>year</th>
#       <th>pregnancyratelt15</th>
#       <th>pregnancyrate1517</th>
#       <th>pregnancyrate1819</th>
#       <th>pregnancyrate1519</th>
#       <th>pregnancyratelt20</th>
#       <th>pregnancyrate2024</th>
#       <th>pregnancyrate2529</th>
#       <th>pregnancyrate3034</th>
#       <th>pregnancyrate3539</th>
#       <th>pregnancyrate40plus</th>
#       <th>abortionratelt15</th>
#       <th>abortionrate1517</th>
#       <th>abortionrate1819</th>
#       <th>abortionrate1519</th>
#       <th>abortionratelt20</th>
#       <th>abortionrate2024</th>
#       <th>abortionrate2529</th>
#       <th>abortionrate3034</th>
#       <th>abortionrate3539</th>
#       <th>abortionrate40plus</th>
#       <th>birthratelt15</th>
#       <th>birthrate1517</th>
#       <th>birthrate1819</th>
#       <th>birthrate1519</th>
# ...
